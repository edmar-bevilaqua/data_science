# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

subscription_id = "534bbb2d-e11d-400a-86cf-17d823e7e559"
resource_group = "azure-machine-learning-path"
workspace = "mlw-dp100-labs"

ml_client = MLClient(
    DefaultAzureCredential(), subscription_id, resource_group, workspace
)
# Out:
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %%
from azure.ai.ml import command

# configure job
job = command(
    command="echo 'Ola, Mundo!'",
    environment="mlw-dp100-labs-environment:1",
)

# connect to workspace and submit job
returned_job = ml_client.create_or_update(job)
# Out:
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %%
job = command(
    command="echo 'hello world'",
    environment="azureml://registries/azureml/environments/sklearn-1.5/labels/latest",
)

# Submit the job
returned_job = ml_client.create_or_update(job)
print(f"Job submitted: {returned_job.name}")
# Out:
# DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	WorkloadIdentityCredential: WorkloadIdentityCredential authentication unavailable. The workload options are not fully configured. See the troubleshooting guide for more information: https://aka.ms/azsdk/python/identity/workloadidentitycredential/troubleshoot. Missing required arguments: 'tenant_id', 'client_id', 'token_file_path'.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	VisualStudioCodeCredential: VisualStudioCodeCredential requires the 'azure-identity-broker' package to be installed. You must also ensure you have the Azure Resources extension installed and have signed in to Azure via Visual Studio Code.
# 	AzureCliCredential: ERROR: V2Error: invalid_grant AADSTS700082: The refresh token has expired due to inactivity. The token was issued on 2025-10-22T19:13:19.0617004Z and was inactive for 90.00:00:00. Trace ID: 49470e52-fc0c-4ab2-885d-f55c727e0d00 Correlation ID: f3270d8a-7d77-4557-b744-92ac9974fa6b Timestamp: 2026-01-30 02:15:25Z. Status: Response_Status.Status_InteractionRequired, Error code: 3399614467, Tag: 558133255
# Run the command below to authenticate interactively; additional arguments may be added as needed:
# az logout
# az login --tenant "86b31d04-0222-4e0f-adb6-c46fdd36e439" --scope "https://management.azure.com/.default"
#
# 	AzurePowerShellCredential: Az.Account module >= 2.2.0 is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	BrokerCredential: InteractiveBrowserBrokerCredential unavailable. The 'azure-identity-broker' package is required to use brokered authentication.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
# ---------------------------------------------------------------------------
# ClientAuthenticationError                 Traceback (most recent call last)
# Cell In[9], line 7
#       1 job = command(
#       2     command="echo 'hello world'",
#       3     environment="azureml://registries/azureml/environments/sklearn-1.5/labels/latest",
#       4 )
#       6 # Submit the job
# ----> 7 returned_job = ml_client.create_or_update(job)
#       8 print(f"Job submitted: {returned_job.name}")
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\ai\ml\_ml_client.py:1306, in MLClient.create_or_update(self, entity, **kwargs)
#    1290 def create_or_update(
#    1291     self,
#    1292     entity: T,
#    1293     **kwargs,
#    1294 ) -> T:
#    1295     """Creates or updates an Azure ML resource.
#    1296
#    1297     :param entity: The resource to create or update.
#    (...)
#    1303         , ~azure.ai.ml.entities.Environment, ~azure.ai.ml.entities.Component, ~azure.ai.ml.entities.Datastore]
#    1304     """
# -> 1306     return _create_or_update(entity, self._operation_container.all_operations, **kwargs)
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\functools.py:912, in singledispatch.<locals>.wrapper(*args, **kw)
#     908 if not args:
#     909     raise TypeError(f'{funcname} requires at least '
#     910                     '1 positional argument')
# --> 912 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\ai\ml\_ml_client.py:1365, in _(entity, operations, **kwargs)
#    1362 @_create_or_update.register(Job)
#    1363 def _(entity: Job, operations, **kwargs):
#    1364     module_logger.debug("Creating or updating job")
# -> 1365     return operations[AzureMLResourceType.JOB].create_or_update(entity, **kwargs)
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\core\tracing\decorator.py:138, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     136             for key, value in span_attributes.items():
#     137                 span.add_attribute(key, value)  # type: ignore
# --> 138             return func(*args, **kwargs)
#     139 else:
#     140     # Native path
#     141     config = {}
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\ai\ml\_telemetry\activity.py:371, in monitor_with_telemetry_mixin.<locals>.monitor.<locals>.wrapper(*args, **kwargs)
#     369 dimensions = {**parameter_dimensions, **(custom_dimensions or {})}
#     370 with log_activity(logger, activity_name or f.__name__, activity_type, dimensions) as activityLogger:
# --> 371     return_value = f(*args, **kwargs)
#     372     if not parameter_dimensions:
#     373         # collect from return if no dimensions from parameter
#     374         activityLogger.activity_info.update(_collect_from_return_value(return_value))
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\ai\ml\operations\_job_operations.py:713, in JobOperations.create_or_update(self, job, description, compute, tags, experiment_name, skip_validation, **kwargs)
#     707 if (rest_job_resource.properties.job_type == RestJobType.PIPELINE) or (
#     708     hasattr(rest_job_resource.properties, "identity")
#     709     and (isinstance(rest_job_resource.properties.identity, UserIdentity))
#     710 ):
#     711     self._set_headers_with_user_aml_token(kwargs)
# --> 713 result = self._create_or_update_with_different_version_api(rest_job_resource=rest_job_resource, **kwargs)
#     715 if is_local_run(result):
#     716     ws_base_url = self._all_operations.all_operations[
#     717         AzureMLResourceType.WORKSPACE
#     718     ]._operation._client._base_url
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\ai\ml\operations\_job_operations.py:761, in JobOperations._create_or_update_with_different_version_api(self, rest_job_resource, **kwargs)
#     758 if rest_job_resource.properties.job_type == RestJobType.COMMAND:
#     759     service_client_operation = self.service_client_01_2025_preview.jobs
# --> 761 result = service_client_operation.create_or_update(
#     762     id=rest_job_resource.name,
#     763     resource_group_name=self._operation_scope.resource_group_name,
#     764     workspace_name=self._workspace_name,
#     765     body=rest_job_resource,
#     766     **kwargs,
#     767 )
#     769 return result
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\core\tracing\decorator.py:138, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     136             for key, value in span_attributes.items():
#     137                 span.add_attribute(key, value)  # type: ignore
# --> 138             return func(*args, **kwargs)
#     139 else:
#     140     # Native path
#     141     config = {}
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\ai\ml\_restclient\v2025_01_01_preview\operations\_jobs_operations.py:622, in JobsOperations.create_or_update(self, resource_group_name, workspace_name, id, body, **kwargs)
#     619 request = _convert_request(request)
#     620 request.url = self._client.format_url(request.url)
# --> 622 pipeline_response = self._client._pipeline.run(  # pylint: disable=protected-access
#     623     request,
#     624     stream=False,
#     625     **kwargs
#     626 )
#     627 response = pipeline_response.http_response
#     629 if response.status_code not in [200, 201]:
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\core\pipeline\_base.py:242, in Pipeline.run(self, request, **kwargs)
#     240 pipeline_request: PipelineRequest[HTTPRequestType] = PipelineRequest(request, context)
#     241 first_node = self._impl_policies[0] if self._impl_policies else _TransportRunner(self._transport)
# --> 242 return first_node.send(pipeline_request)
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 98 (2 times)]
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\mgmt\core\policies\_base.py:95, in ARMAutoResourceProviderRegistrationPolicy.send(self, request)
#      93 def send(self, request: PipelineRequest[HTTPRequestType]) -> PipelineResponse[HTTPRequestType, HTTPResponseType]:
#      94     http_request = request.http_request
# ---> 95     response = self.next.send(request)
#      96     if response.http_response.status_code == 409:
#      97         rp_name = self._check_rp_not_registered_err(response)
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\core\pipeline\policies\_redirect.py:205, in RedirectPolicy.send(self, request)
#     203 original_domain = get_domain(request.http_request.url) if redirect_settings["allow"] else None
#     204 while retryable:
# --> 205     response = self.next.send(request)
#     206     redirect_location = self.get_redirect_location(response)
#     207     if redirect_location and redirect_settings["allow"]:
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\core\pipeline\policies\_retry.py:545, in RetryPolicy.send(self, request)
#     543 self._configure_timeout(request, absolute_timeout, is_response_error)
#     544 request.context["retry_count"] = len(retry_settings["history"])
# --> 545 response = self.next.send(request)
#     546 if self.is_retry(retry_settings, response):
#     547     retry_active = self.increment(retry_settings, response=response)
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:159, in BearerTokenCredentialPolicy.send(self, request)
#     151 def send(self, request: PipelineRequest[HTTPRequestType]) -> PipelineResponse[HTTPRequestType, HTTPResponseType]:
#     152     """Authorize request with a bearer token and send it to the next policy
#     153
#     154     :param request: The pipeline request object
#    (...)
#     157     :rtype: ~azure.core.pipeline.PipelineResponse
#     158     """
# --> 159     self.on_request(request)
#     160     try:
#     161         response = self.next.send(request)
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:134, in BearerTokenCredentialPolicy.on_request(self, request)
#     131 self._enforce_https(request)
#     133 if self._token is None or self._need_new_token:
# --> 134     self._request_token(*self._scopes)
#     135 bearer_token = cast(Union["AccessToken", "AccessTokenInfo"], self._token).token
#     136 self._update_headers(request.http_request.headers, bearer_token)
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:110, in _BearerTokenCredentialPolicyBase._request_token(self, *scopes, **kwargs)
#     103 def _request_token(self, *scopes: str, **kwargs: Any) -> None:
#     104     """Request a new token from the credential.
#     105
#     106     This will call the credential's appropriate method to get a token and store it in the policy.
#     107
#     108     :param str scopes: The type of access needed.
#     109     """
# --> 110     self._token = self._get_token(*scopes, **kwargs)
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:100, in _BearerTokenCredentialPolicyBase._get_token(self, *scopes, **kwargs)
#      97         if key in TokenRequestOptions.__annotations__:  # pylint: disable=no-member
#      98             options[key] = kwargs.pop(key)  # type: ignore[literal-required]
# --> 100     return cast(SupportsTokenInfo, self._credential).get_token_info(*scopes, options=options)
#     101 return cast(TokenCredential, self._credential).get_token(*scopes, **kwargs)
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\identity\_credentials\default.py:375, in DefaultAzureCredential.get_token_info(self, options, *scopes)
#     373 within_dac.set(True)
#     374 try:
# --> 375     token_info = cast(SupportsTokenInfo, super()).get_token_info(*scopes, options=options)
#     376 finally:
#     377     within_dac.set(False)
#
# File c:\Users\edmar\AppData\Local\Programs\Python\Python312\Lib\site-packages\azure\identity\_credentials\chained.py:225, in ChainedTokenCredential.get_token_info(self, options, *scopes)
#     217 message = (
#     218     self.__class__.__name__
#     219     + " failed to retrieve a token from the included credentials."
#    (...)
#     222     "https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot."
#     223 )
#     224 _LOGGER.warning(message)
# --> 225 raise ClientAuthenticationError(message=message)
#
# ClientAuthenticationError: DefaultAzureCredential failed to retrieve a token from the included credentials.
# Attempted credentials:
# 	EnvironmentCredential: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 	WorkloadIdentityCredential: WorkloadIdentityCredential authentication unavailable. The workload options are not fully configured. See the troubleshooting guide for more information: https://aka.ms/azsdk/python/identity/workloadidentitycredential/troubleshoot. Missing required arguments: 'tenant_id', 'client_id', 'token_file_path'.
# 	ManagedIdentityCredential: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 	SharedTokenCacheCredential: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 	VisualStudioCodeCredential: VisualStudioCodeCredential requires the 'azure-identity-broker' package to be installed. You must also ensure you have the Azure Resources extension installed and have signed in to Azure via Visual Studio Code.
# 	AzureCliCredential: ERROR: V2Error: invalid_grant AADSTS700082: The refresh token has expired due to inactivity. The token was issued on 2025-10-22T19:13:19.0617004Z and was inactive for 90.00:00:00. Trace ID: 49470e52-fc0c-4ab2-885d-f55c727e0d00 Correlation ID: f3270d8a-7d77-4557-b744-92ac9974fa6b Timestamp: 2026-01-30 02:15:25Z. Status: Response_Status.Status_InteractionRequired, Error code: 3399614467, Tag: 558133255
# Run the command below to authenticate interactively; additional arguments may be added as needed:
# az logout
# az login --tenant "86b31d04-0222-4e0f-adb6-c46fdd36e439" --scope "https://management.azure.com/.default"
#
# 	AzurePowerShellCredential: Az.Account module >= 2.2.0 is not installed
# 	AzureDeveloperCliCredential: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# 	BrokerCredential: InteractiveBrowserBrokerCredential unavailable. The 'azure-identity-broker' package is required to use brokered authentication.
# To mitigate this issue, please refer to the troubleshooting guidelines here at https://aka.ms/azsdk/python/identity/defaultazurecredential/troubleshoot.
