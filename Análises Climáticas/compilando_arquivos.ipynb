# %%
from itertools import islice
import csv
import os
import pandas as pd

# %%
arquivos = os.listdir(path="C:\\Users\\edmar\\OneDrive\\Documents\\Trabalho\\CMPC\\Análises Climáticas\\Dados INMET")
arquivos_com_caminho = []
for i in arquivos:
    arquivos_com_caminho.append("C:\\Users\\edmar\\OneDrive\\Documents\\Trabalho\\CMPC\\Análises Climáticas\\Dados INMET\\"+i)

# %%
compilado = pd.DataFrame(columns=['Data', 'Hora UTC', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (Kj/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)', 'Unnamed: 19', 'Estação', 'Latitude',
       'Longitude'])

# %%
for doc in arquivos_com_caminho:
    with open(file=doc, newline='', encoding='ANSI') as file:
        reader = csv.reader(file, delimiter=';')
        linha3 = next(islice(reader, 2, 3))
        linha4 = next(islice(reader, 1, 2))
        linha5 = next(islice(reader, 0, 1))
        estacao = linha3[1]
        latitude = linha4[1]
        longitude = linha5[1]

    tmp = pd.read_csv(filepath_or_buffer=doc, encoding='ANSI', sep=';', skiprows=8)
    tmp['Estação'] = estacao
    tmp['Latitude'] = latitude
    tmp['Longitude'] = longitude
    compilado = pd.concat([compilado, tmp])

# %%
compilado
# Out:
#            Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0    2022/01/01  0000 UTC                                0
# 1    2022/01/01  0100 UTC                                0
# 2    2022/01/01  0200 UTC                                0
# 3    2022/01/01  0300 UTC                                0
# 4    2022/01/01  0400 UTC                                0
# ..          ...       ...                              ...
# 571  2022/12/31  1900 UTC                                0
# 572  2022/12/31  2000 UTC                                0
# 573  2022/12/31  2100 UTC                                0
# 574  2022/12/31  2200 UTC                                0
# 575  2022/12/31  2300 UTC                                0
#
#     PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                               1000,3
# 1                                               1000,6
# 2                                               1000,5
# ...

# %%
compilado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1552152 entries, 0 to 575
# Data columns (total 23 columns):
#  #   Column                                                 Non-Null Count    Dtype
# ---  ------                                                 --------------    -----
#  0   Data                                                   1552152 non-null  object
#  1   Hora UTC                                               1552152 non-null  object
#  2   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       1373512 non-null  object
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  1409172 non-null  object
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        1408264 non-null  object
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       1408264 non-null  object
#  6   RADIACAO GLOBAL (Kj/m²)                                772023 non-null   object
#  7   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           1415010 non-null  object
# ...

# %%
compilado.drop(columns=['Unnamed: 19', 'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)', 'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
                        'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)', 'RADIACAO GLOBAL (Kj/m²)', 'TEMPERATURA DO PONTO DE ORVALHO (°C)', 'VENTO, DIREÇÃO HORARIA (gr) (° (gr))',
                        'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)', 'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)', 'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
                        'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)', 'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)', 'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)', 'VENTO, RAJADA MAXIMA (m/s)'], inplace=True)

# %%
compilado['Hora UTC'].unique()
# Out:
# array(['0000 UTC', '0100 UTC', '0200 UTC', '0300 UTC', '0400 UTC',
#        '0500 UTC', '0600 UTC', '0700 UTC', '0800 UTC', '0900 UTC',
#        '1000 UTC', '1100 UTC', '1200 UTC', '1300 UTC', '1400 UTC',
#        '1500 UTC', '1600 UTC', '1700 UTC', '1800 UTC', '1900 UTC',
#        '2000 UTC', '2100 UTC', '2200 UTC', '2300 UTC'], dtype=object)

# %%
corretos = ['00:00:00','00:30:00','01:00:00','01:30:00','02:00:00','02:30:00',
            '03:00:00','03:30:00','04:00:00','04:30:00','05:00:00','05:30:00',
            '06:00:00','06:30:00','07:00:00','07:30:00','08:00:00','08:30:00',
            '09:00:00','09:30:00','10:00:00','10:30:00','11:00:00','11:30:00',
            '12:00:00','12:30:00','13:00:00','13:30:00','14:00:00','14:30:00',
            '15:00:00','15:30:00','16:00:00','16:30:00','17:00:00','17:30:00',
            '18:00:00','18:30:00','19:00:00','19:30:00','20:00:00','20:30:00',
            '21:00:00','21:30:00','22:00:00','22:30:00','23:00:00','23:30:00']

incorretos = ['0000 UTC', '0100 UTC', '0200 UTC', '0300 UTC', '0400 UTC',
              '0500 UTC', '0600 UTC', '0700 UTC', '0800 UTC', '0900 UTC',
              '1000 UTC', '1100 UTC', '1200 UTC', '1300 UTC', '1400 UTC',
              '1500 UTC', '1600 UTC', '1700 UTC', '1800 UTC', '1900 UTC',
              '2000 UTC', '2100 UTC', '2200 UTC', '2300 UTC']

# %%
def limpa_horas(df)
    to_remove = []
    for i, j in enumerate(df):
        if '30' in j:
            to_remove.append(i)
    to_remove = sorted(to_remove, reverse=True)
    for i in to_remove:
        del df[i]

# %%
for i in range (0, len(corretos), 1):
    compilado.replace(to_replace=incorretos[i], value=corretos[i], inplace=True)

# %%
compilado
# Out:
#            Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0    2022/01/01  00:00:00                                0
# 1    2022/01/01  01:00:00                                0
# 2    2022/01/01  02:00:00                                0
# 3    2022/01/01  03:00:00                                0
# 4    2022/01/01  04:00:00                                0
# ..          ...       ...                              ...
# 571  2022/12/31  19:00:00                                0
# 572  2022/12/31  20:00:00                                0
# 573  2022/12/31  21:00:00                                0
# 574  2022/12/31  22:00:00                                0
# 575  2022/12/31  23:00:00                                0
#
#     TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                             25
# 1                                           24,1
# 2                                           23,6
# 3                                           23,3
# ...

# %%
from datetime import datetime as dt

# %%
compilado['Data'] = pd.to_datetime(compilado['Data'], dayfirst=True)

# %%
compilado['Ano'] = compilado['Data'].dt.strftime('%Y')

# %%
compilado
# Out:
#           Data  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0   2022-01-01  00:00:00                                0
# 1   2022-01-01  01:00:00                                0
# 2   2022-01-01  02:00:00                                0
# 3   2022-01-01  03:00:00                                0
# 4   2022-01-01  04:00:00                                0
# ..         ...       ...                              ...
# 571 2022-12-31  19:00:00                                0
# 572 2022-12-31  20:00:00                                0
# 573 2022-12-31  21:00:00                                0
# 574 2022-12-31  22:00:00                                0
# 575 2022-12-31  23:00:00                                0
#
#     TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                             25
# 1                                           24,1
# 2                                           23,6
# 3                                           23,3
# ...

# %%
compilado = compilado[['Estação', 'Ano', 'Data', 'Latitude', 'Longitude', 'Hora UTC', 
                       'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
                       'UMIDADE RELATIVA DO AR, HORARIA (%)', 'VENTO, VELOCIDADE HORARIA (m/s)']]

# %%
compilado
# Out:
#                             Estação   Ano       Data      Latitude  \
# 0    PORTO ALEGRE - JARDIM BOTANICO  2022 2022-01-01  -30,05361111
# 1    PORTO ALEGRE - JARDIM BOTANICO  2022 2022-01-01  -30,05361111
# 2    PORTO ALEGRE - JARDIM BOTANICO  2022 2022-01-01  -30,05361111
# 3    PORTO ALEGRE - JARDIM BOTANICO  2022 2022-01-01  -30,05361111
# 4    PORTO ALEGRE - JARDIM BOTANICO  2022 2022-01-01  -30,05361111
# ..                              ...   ...        ...           ...
# 571        PORTO ALEGRE- BELEM NOVO  2022 2022-12-31   -30,1861111
# 572        PORTO ALEGRE- BELEM NOVO  2022 2022-12-31   -30,1861111
# 573        PORTO ALEGRE- BELEM NOVO  2022 2022-12-31   -30,1861111
# 574        PORTO ALEGRE- BELEM NOVO  2022 2022-12-31   -30,1861111
# 575        PORTO ALEGRE- BELEM NOVO  2022 2022-12-31   -30,1861111
#
#         Longitude  Hora UTC PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0    -51,17472221  00:00:00                                0
# ...

# %%
compilado.to_csv("Estações_INMET_2020_A_2023_RS.csv", index=False)
