# %% [markdown]
# # Relatório de An;alise VIII
# ---
# ## Importanto Bibliotecas

# %%
import pandas as pd

# %%
df = pd.read_csv('./aluguel_residencial_completo.csv', sep= ';', header= 0)
df.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0   1700.0       500.0  60.0     42.50   Apartamento
# 1   7000.0         0.0   0.0     70.00          Casa
# ...

# %%
selection = df.groupby(df['Tipo'])

# %%
selection['Quartos'].describe()
# Out:
#                       count      mean       std  min  25%  50%  75%   max
# Tipo
# Apartamento         18780.0  2.499095  0.932888  0.0  2.0  2.0  3.0  14.0
# Casa                  965.0  3.133679  1.659799  0.0  2.0  3.0  4.0  14.0
# Casa de Condomínio    996.0  4.007028  1.185741  1.0  3.0  4.0  5.0  11.0
# Casa de Vila          249.0  1.927711  0.956090  0.0  1.0  2.0  2.0   6.0
# Quitinete             836.0  0.834928  0.374678  0.0  1.0  1.0  1.0   2.0

# %%
rotulos = ['0 a 2 quart0s', '3 a 4 quartos', '4 a 6 quartos', '7 ou mais quartos']

# %%
classes = [0, 2, 4, 6, 14]
quartos = pd.cut(
    df['Quartos'],
    bins= classes,
    labels= rotulos
)
quartos.value_counts()
# Out:
# 0 a 2 quart0s        11250
# 3 a 4 quartos         9681
# 4 a 6 quartos          686
# 7 ou mais quartos       50
# Name: Quartos, dtype: int64

# %%
quartos.value_counts()
# Out:
# (0, 2]     11250
# (2, 4]      9681
# (4, 6]       686
# (6, 14]       50
# Name: Quartos, dtype: int64
